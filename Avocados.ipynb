# %% [markdown]
# #                                                Avacado Project

# %% [markdown]
# This data was downloaded from the Hass Avocado Board website in May of 2018 & compiled into a single CSV.
#
# The table below represents weekly 2018 retail scan data for National retail volume (units) and price. Retail scan data comes directly from retailers’ cash registers based on actual retail sales of Hass avocados.
#
# Starting in 2013, the table below reflects an expanded, multi-outlet retail data set. Multi-outlet reporting includes an aggregation of the following channels: grocery, mass, club, drug, dollar and military. The Average Price (of avocados) in the table reflects a per unit (per avocado) cost, even when multiple units (avocados) are sold in bags.
#
# The Product Lookup codes (PLU’s) in the table are only for Hass avocados. Other varieties of avocados (e.g. greenskins) are not included in this table.
#
# Some relevant columns in the dataset:
#
# Date - The date of the observation
# AveragePrice - the average price of a single avocado
# type - conventional or organic
# year - the year
# Region - the city or region of the observation
# Total Volume - Total number of avocados sold
# 4046 - Total number of avocados with PLU 4046 sold
# 4225 - Total number of avocados with PLU 4225 sold
# 4770 - Total number of avocados with PLU 4770 sold

# %%
# import important liblaries

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Loading Data Set into variable:

# %%
# print top data

df=pd.read_csv(r'C:\Users\Vishakha Avhad\Desktop\avocado.csv')

df.head(20)
# Out:
#     Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0            0  27/12/2015          1.33      64236.62  1036.74   54454.85
# 1            1  20/12/2015          1.35      54876.98   674.28   44638.81
# 2            2  13/12/2015          0.93     118220.22   794.70  109149.67
# 3            3   6/12/2015          1.08      78992.15  1132.00   71976.41
# 4            4  29/11/2015          1.28      51039.60   941.48   43838.39
# 5            5  22/11/2015          1.26      55979.78  1184.27   48067.99
# 6            6  15/11/2015          0.99      83453.76  1368.92   73672.72
# 7            7   8/11/2015          0.98     109428.33   703.75  101815.36
# 8            8   1/11/2015          1.02      99811.42  1022.15   87315.57
# 9            9  25/10/2015          1.07      74338.76   842.40   64757.44
# 10          10  18/10/2015          1.12      84843.44   924.86   75595.85
# ...

# %% [markdown]
# Load data set

# %% [markdown]
# # Exploratory Data Analysis:

# %%
df.drop('Unnamed: 0',inplace=True,axis=1)

# %% [markdown]
# remove the Unnamed: 0 coloumn

# %%
df.head()
# Out:
#          Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0  27/12/2015          1.33      64236.62  1036.74   54454.85   48.16
# 1  20/12/2015          1.35      54876.98   674.28   44638.81   58.33
# 2  13/12/2015          0.93     118220.22   794.70  109149.67  130.50
# 3   6/12/2015          1.08      78992.15  1132.00   71976.41   72.58
# 4  29/11/2015          1.28      51039.60   941.48   43838.39   75.78
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  region
# 0     8696.87     8603.62       93.25          0.0  conventional  2015  Albany
# 1     9505.56     9408.07       97.49          0.0  conventional  2015  Albany
# 2     8145.35     8042.21      103.14          0.0  conventional  2015  Albany
# 3     5811.16     5677.40      133.76          0.0  conventional  2015  Albany
# 4     6183.95     5986.26      197.69          0.0  conventional  2015  Albany

# %% [markdown]
# after removing Unnamed: 0 column print data set

# %%
pd.set_option('display.max_row',None)

# %%
# describe information about dataset

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1517 entries, 0 to 1516
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          1517 non-null   object
#  1   AveragePrice  1517 non-null   float64
#  2   Total Volume  1517 non-null   float64
#  3   4046          1517 non-null   float64
#  4   4225          1517 non-null   float64
#  5   4770          1517 non-null   float64
#  6   Total Bags    1517 non-null   float64
#  7   Small Bags    1517 non-null   float64
#  8   Large Bags    1517 non-null   float64
#  9   XLarge Bags   1517 non-null   float64
#  10  type          1517 non-null   object
#  11  year          1517 non-null   int64
#  12  region        1517 non-null   object
# dtypes: float64(9), int64(1), object(3)
# memory usage: 154.2+ KB

# %% [markdown]
# in this data set we don't have missing data and we have object,float, integer data type

# %%
# describe statistical information

df.describe()
# Out:
#        AveragePrice  Total Volume          4046          4225          4770  \
# count   1517.000000  1.517000e+03  1.517000e+03  1.517000e+03  1.517000e+03
# mean       1.074990  1.601879e+06  6.464387e+05  6.114375e+05  5.040550e+04
# std        0.188891  4.433143e+06  1.947614e+06  1.672906e+06  1.377812e+05
# min        0.490000  3.875074e+04  4.677200e+02  1.783770e+03  0.000000e+00
# 25%        0.980000  1.474700e+05  2.040034e+04  4.147606e+04  9.112500e+02
# 50%        1.080000  4.027919e+05  8.175117e+04  1.186649e+05  7.688170e+03
# 75%        1.190000  9.819751e+05  3.775785e+05  4.851503e+05  2.916730e+04
# max        1.680000  4.465546e+07  1.893304e+07  1.895648e+07  1.381516e+06
#
#          Total Bags    Small Bags    Large Bags    XLarge Bags         year
# count  1.517000e+03  1.517000e+03  1.517000e+03    1517.000000  1517.000000
# mean   2.935974e+05  2.487736e+05  4.264205e+04    2181.771074  2015.162821
# ...

# %%
#find row and coloumn

df.shape
# Out:
# (1517, 13)

# %% [markdown]
# in this data set we have 1517 row and 13 column.

# %%
#find null value in dataset

df.isnull().sum()
# Out:
# Date            0
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# dtype: int64

# %% [markdown]
# there is no null data present in data set

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# null data present heat map

# %%
df.columns
# Out:
# Index(['Date', 'AveragePrice', 'Total Volume', '4046', '4225', '4770',
#        'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type', 'year',
#        'region'],
#       dtype='object')

# %% [markdown]
# print the all 13 column name

# %%
# find duplicate row in dataset

print(df.duplicated(keep='last'))
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18      False
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 24      False
# 25      False
# 26      False
# 27      False
# 28      False
# 29      False
# 30      False
# 31      False
# 32      False
# 33      False
# 34      False
# 35      False
# 36      False
# 37      False
# 38      False
# 39      False
# 40      False
# 41      False
# 42      False
# 43      False
# 44      False
# 45      False
# 46      False
# 47      False
# 48      False
# 49      False
# 50      False
# 51      False
# 52      False
# 53      False
# 54      False
# 55      False
# 56      False
# 57      False
# 58      False
# 59      False
# 60      False
# 61      False
# ...

# %% [markdown]
# in this data set we don't have duplicate row.

# %%
df.groupby('year')['type'].value_counts()
# Out:
# year  type
# 2015  conventional    1270
# 2016  conventional     247
# Name: type, dtype: int64

# %% [markdown]
# we have conventional type of Avocados and having 2 year data 2015 and 2016

# %%
#find the correlation

cor=df.corr()
cor
# Out:
#               AveragePrice  Total Volume      4046      4225      4770  \
# AveragePrice      1.000000     -0.140470 -0.190096 -0.092084 -0.100567
# Total Volume     -0.140470      1.000000  0.985568  0.987154  0.934347
# 4046             -0.190096      0.985568  1.000000  0.951952  0.898570
# 4225             -0.092084      0.987154  0.951952  1.000000  0.927757
# 4770             -0.100567      0.934347  0.898570  0.927757  1.000000
# Total Bags       -0.111597      0.967689  0.930395  0.951779  0.926405
# Small Bags       -0.097682      0.960642  0.922278  0.943988  0.923607
# Large Bags       -0.177480      0.910226  0.884229  0.900496  0.840523
# XLarge Bags      -0.048284      0.521717  0.474063  0.504718  0.646053
# year              0.178683     -0.004189 -0.040439 -0.007254  0.029222
#
#               Total Bags  Small Bags  Large Bags  XLarge Bags      year
# AveragePrice   -0.111597   -0.097682   -0.177480    -0.048284  0.178683
# ...

# %% [markdown]
# in this data set all feature has negative correlation with avgerage price which is the target in this data set except year .
# year has positive correlation .

# %%
#prepare heat map for correlation
plt.subplots(figsize=(10,10))
sns.heatmap(cor,annot=True,linewidth=0.1,linecolor="black",cmap="YlGnBu")
# Out:
# <AxesSubplot:>

# %% [markdown]
# total bags and small bags has highest .

# %%
plt.figure(figsize=(22,7))
df.corr()["AveragePrice"].sort_values(ascending=False).drop(["AveragePrice"]).plot(kind='bar',color='c')
plt.xlabel('Feature',fontsize=19)
plt.ylabel('coloumn with Target names',fontsize=19)
plt.title('correlation',fontsize=18)
plt.show()

# %% [markdown]
# # Data Visualization:

# %%
sns.barplot(x="year",y="AveragePrice",data=df)
# Out:
# <AxesSubplot:xlabel='year', ylabel='AveragePrice'>

# %% [markdown]
# in 2016 average price of avocado has high.

# %%
df['Date']=pd.to_datetime(df['Date'])
df['Month']=df['Date'].apply(lambda x:x.month)
df['Day']=df['Date'].apply(lambda x:x.day)

# %% [markdown]
# Now let's do some Feature Engineering on the Date Feature so we can be able to use the day and the month columns in building our machine learning model later.

# %%
sns.barplot(x="Month",y="AveragePrice",data=df)
# Out:
# <AxesSubplot:xlabel='Month', ylabel='AveragePrice'>

# %% [markdown]
# in novber avocados has higest average price.

# %%
byDate=df.groupby('Date').mean()
plt.figure(figsize=(14,8))
byDate['AveragePrice'].plot()
plt.title('Average Price')
# Out:
# Text(0.5, 1.0, 'Average Price')

# %% [markdown]
# average price is increase year by year

# %%
df['region'].nunique()
# Out:
# 51

# %% [markdown]
# there are 51 region

# %%
df['type'].nunique()
# Out:
# 1

# %% [markdown]
# there is one type of Avocado present in data set.

# %%
sns.pairplot(df)

# %% [markdown]
# checking outlier

# %%
df.boxplot(figsize=(20,12))
plt.subplots_adjust()
plt.show()

# %%
df.skew() #greater than +0.5 less than -0.5
# Out:
# AveragePrice   -0.109444
# Total Volume    6.200138
# 4046            6.051830
# 4225            6.394926
# 4770            5.405164
# Total Bags      5.366378
# Small Bags      5.355185
# Large Bags      5.144495
# XLarge Bags     5.775077
# year            1.828332
# Month           0.101439
# Day             0.041303
# dtype: float64

# %% [markdown]
# XLarge Bags,4225,4046,Total Volume  has more skew

# %%
df.hist(figsize=(20,20))
plt.show()

# %%
df1=pd.get_dummies(df.drop(['region','Date'],axis=1),drop_first=True)

# %%
df1.head()
# Out:
#    AveragePrice  Total Volume     4046       4225    4770  Total Bags  \
# 0          1.33      64236.62  1036.74   54454.85   48.16     8696.87
# 1          1.35      54876.98   674.28   44638.81   58.33     9505.56
# 2          0.93     118220.22   794.70  109149.67  130.50     8145.35
# 3          1.08      78992.15  1132.00   71976.41   72.58     5811.16
# 4          1.28      51039.60   941.48   43838.39   75.78     6183.95
#
#    Small Bags  Large Bags  XLarge Bags  year  Month  Day
# 0     8603.62       93.25          0.0  2015     12   27
# 1     9408.07       97.49          0.0  2015     12   20
# 2     8042.21      103.14          0.0  2015     12   13
# 3     5677.40      133.76          0.0  2015      6   12
# 4     5986.26      197.69          0.0  2015     11   29

# %% [markdown]
# plt.figure(figsize=(22,7))
# df.corr()["W"].sort_values(ascending=False).drop(["W"]).plot(kind='bar',color='c')
# plt.xlabel('Feature',fontsize=19)
# plt.ylabel('coloumn with Target names',fontsize=19)
# plt.title('correlation',fontsize=18)
# plt.show()

# %%
X=df1.iloc[:,1:14]
y=df1['AveragePrice']
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=40)

# %% [markdown]
# divide the data in target and feature .in x variable define the feture variable and y variable define the target

# %% [markdown]
# scaling the data :

# %%
from sklearn.preprocessing import MinMaxScaler
mns=MinMaxScaler()

# %% [markdown]
# # Creating and Training the Model

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(X_train,y_train)
pred=lr.predict(X_test)

# %%
from sklearn import metrics
print('MAE:', metrics.mean_absolute_error(y_test, pred))
print('MSE:', metrics.mean_squared_error(y_test, pred))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, pred)))
# Out:
# MAE: 0.1324514585290695
# MSE: 0.03141741896728702
# RMSE: 0.17724959511177174

# %%
plt.scatter(x=y_test,y=pred)

# %% [markdown]
# after apply liner regression straight line is not form so,we we try another model.

# %%
from sklearn.tree import DecisionTreeRegressor
dtr=DecisionTreeRegressor()
dtr.fit(X_train,y_train)
pred=dtr.predict(X_test)

# %%
plt.scatter(x=y_test,y=pred)
plt.xlabel('Y Test')
plt.ylabel('Predicted Y')
# Out:
# Text(0, 0.5, 'Predicted Y')

# %%
print('MAE:', metrics.mean_absolute_error(y_test, pred))
print('MSE:', metrics.mean_squared_error(y_test, pred))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, pred)))
# Out:
# MAE: 0.05690098684210521
# MSE: 0.0060380595065789395
# RMSE: 0.07770495162201016

# %% [markdown]
# after applying desion tree model RMSE is decress.so decision tree model is better than linear regression.

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor()
rf.fit(X_train,y_train)
pred=rdr.predict(X_test)

# %%
print('MAE:', metrics.mean_absolute_error(y_test, pred))
print('MSE:', metrics.mean_squared_error(y_test, pred))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, pred)))
# Out:
# MAE: 0.05690098684210521
# MSE: 0.0060380595065789395
# RMSE: 0.07770495162201016

# %% [markdown]
# we try the randomforest tree model and finally we decided randomforest tree model is the best model.

# %%
sns.distplot((y_test-pred),bins=50)
# Out:
# <AxesSubplot:xlabel='AveragePrice', ylabel='Density'>

# %%
import bz2
import pickle
filename="result.pk1"
pickle.dump(rf,open(filename,'wb'))

# %% [markdown]
# # Conclusion:

# %%
loaded_model=pickle.load(open('result.pk1','rb'))
result=loaded_model.score(X_test,y_test)
print(result)
# Out:
# 0.844498342106083

# %%
this modle give 84% accuracy

# %%
conclusion = pd.DataFrame({'Y Test':y_test , 'Pred':pred},columns=['Y Test','Pred'])
sns.lmplot(x='Y Test',y='Pred',data=data,palette='rainbow')
conclusion.head()
# Out:
#       Y Test    Pred
# 1261    0.84  0.8130
# 168     1.20  1.1882
# 670     1.32  1.2486
# 796     0.51  0.5770
# 50      1.24  1.1071

# %%
test data and predicted value are mounted on straight line.
